# %% [markdown]
# Assumption LR
#
# 1.Linearity
# 2.Normality
# 3.etc etc[]

# %%
def formulae(x):
    return 5*x + 15
x = [_ for _ in range(10)]
y = [formulae(_) for _ in x]
for _ in zip(x,y):
    print(f"X: {_[0]}, Y: {_[1]}")
# Out:
# X: 0, Y: 15
# X: 1, Y: 20
# X: 2, Y: 25
# X: 3, Y: 30
# X: 4, Y: 35
# X: 5, Y: 40
# X: 6, Y: 45
# X: 7, Y: 50
# X: 8, Y: 55
# X: 9, Y: 60

# %%
formulae = lambda x: 5*x + 15

x = [_ for _ in range(10)]
y = [formulae(_) for _ in x]

for _ in zip(x, y):
    print(f"X: {_[0]}, Y: {_[1]}")
# Out:
# X: 0, Y: 15
# X: 1, Y: 20
# X: 2, Y: 25
# X: 3, Y: 30
# X: 4, Y: 35
# X: 5, Y: 40
# X: 6, Y: 45
# X: 7, Y: 50
# X: 8, Y: 55
# X: 9, Y: 60

# %%
import numpy as np

# %%
class ScratchLR:
    """
    A class which implements Linear Regression with OLS from scratch using core pyhton
    
    """
    def __init__(self):
        self.m = 0 # m: slope; m : weights, theta_1
        self.b = 0 # b: intercept; b : bias, theta_0
    
    def fit(self, X_train, y_train):
        self.b = 0.0
        """
        m: slope
        
        """
        
        numerator, denominator = 0, 0, 0.0
        
        for i in range (len(X_train)):
            numerator = (X_train[i] - np.mean(X_train)) * (y_train[i] - np.mean(y_train))
            denominator = (X_train[i] - X_train.mean()) * (X_train[i] - X.mean())
        
        m = numerator / denominator
        b = np.mean(y_train) - m * np.mean(X_train)
        
        self.m, self.b = m, b
        print(f"Slope: or wights{self.m}")
        print(f"Bias: {self.b}")
        
    def predict(self, X_test):
        return self.m * X_test + self.b

# %%
X = [1,2,3,4,5,7,9,12,13,15,18]
y = [2,4,7,8,12,15,16,18,19,20]

assert len(X) == len(y), "Length Mismatch"

# %%
X_train, y_train, X_test, y_test = X[:11], y[:11], X[11:], y[11:]
print(X_train)
print(y_train)
print(X_test)
print(y_test)

# %% [markdown]
# our_model = ScratchLR()
# our_model.fit(X_train, y_train=y_train)

# %%
from sklearn.linear_model import LinearRegression

sklr = LinearRegression()

# %%
sklr.fit()

# %%
class MyLinearRegression:
    def __init__(self):
        self.w = None
        self.b = None

# %%
# %pip install matplotlib seaborn

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

# %matplotlib inline
# Out:
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\suhas\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 4.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.1 MB 3.0 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 3.0 MB/s eta 0:00:03
# ...

# %%
from sklearn.datasets import make_regression

X,y = make_regression(n_samples = 100, #number of observations
                      n_features = 5, #number of columns(aka features)present
                      #n_informative = 5, #number of important features (5) among `n_feautures` (20 in pur case)
                      #IRL; no of important features are unknown and we are sipposed to explore the same
                      # as it's a dummy data generator; we're tuning the data according to our needs
                      noise = 2)# adds randoms by manipulating the spread of the inherant probabilistic distribution of the data

print(f"Shape of the data{X.shape}")
print(f"Shape of the Target: {y.shape}")
print(f"No of sample {X.shape[0]}")
print(f"No of features {X.shape[1]}")
print(f"Similer Cardinaity in Number of samples and No of values in the target: {"Matched" if len(X)== len (y) else "Mismatched"}")
# Out:
# Shape of the data(100, 5)
# Shape of the Target: (100,)
# No of sample 100
# No of features 5
# Similer Cardinaity in Number of samples and No of values in the target: Matched

# %%
df = pd.DataFrame(X,y)
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split as tts_function
from sklearn.impute import SimpleImputer as njan_imputer
from sklearn.linear_model import LinearRegression as LogisticRegression

alpha, beta, gamma, delta = tts_function(X,y, train_size = 0.8)
model = LogisticRegression(n_jobs= -1)
what_to_type_here, what_should_I_put_here = alpha, gamma
model.fit(what_to_type_here, what_should_I_put_here)
# Out:
# LinearRegression(n_jobs=-1)

# %%
pipe = Pipeline([
    ('')
])
