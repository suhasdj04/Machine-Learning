# %% [markdown]
# ## Importing important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("Data/weatherhistory.zip")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Data/weatherhistory.zip")
#       2 df.head()
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:840, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     835 # ZIP Compression
#     836 elif compression == "zip":
#     837     # error: Argument 1 to "_BytesZipFile" has incompatible type
#     838     # "Union[str, BaseBuffer]"; expected "Union[Union[str, PathLike[str]],
#     839     # ReadBuffer[bytes], WriteBuffer[bytes]]"
# --> 840     handle = _BytesZipFile(
#     841         handle,  # type: ignore[arg-type]
#     842         ioargs.mode,
#     843         **compression_args,
#     844     )
#     845     if handle.buffer.mode == "r":
#     846         handles.append(handle)
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:1093, in _BytesZipFile.__init__(self, file, mode, archive_name, **kwargs)
#    1087 kwargs.setdefault("compression", zipfile.ZIP_DEFLATED)
#    1088 # error: No overload variant of "ZipFile" matches argument types
#    1089 # "str | PathLike[str] | ReadBuffer[bytes] | WriteBuffer[bytes]",
#    1090 # "str", "dict[str, Any]"
#    1091 # error: Incompatible types in assignment (expression has type "ZipFile",
#    1092 # base class "_BufferedWriter" defined the type as "BytesIO")
# -> 1093 self.buffer: zipfile.ZipFile = zipfile.ZipFile(  # type: ignore[call-overload, assignment]
#    1094     file, mode, **kwargs
#    1095 )
#
# File c:\Users\suhas\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1336, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1334 while True:
#    1335     try:
# -> 1336         self.fp = io.open(file, filemode)
#    1337     except OSError:
#    1338         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/weatherhistory.zip'

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Understanding the data

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %% [markdown]
# ## Handling missing values

# %%
df.isna().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (95936, 12)

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# ## Retaining numerical columns only

# %%
num_df = df.select_dtypes(exclude="object")

# %%
num_df.head()
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51

# %%
num_df = num_df.drop("Apparent Temperature (C)", axis=1) #Two temperature columns is not required.
X = num_df["Humidity"]
Y = num_df["Temperature (C)"]

# %% [markdown]
# ## Outlier Detection

# %%
plt.figure(figsize=(6,4))
plt.boxplot(X)

plt.title("Boxplot of Humidity")
plt.ylabel("Humidity")
plt.show()

# %%
col = "Humidity"

Q1 = num_df[col].quantile(0.25)
Q3 = num_df[col].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

mask = (num_df[col] >= lower) & (num_df[col] <= upper)
outliers = (num_df[col] < lower) & (num_df[col] > upper)

X = num_df.loc[mask, ["Humidity"]]
Y = num_df.loc[mask, "Temperature (C)"]

# %%
plt.figure(figsize=(6,4))
plt.boxplot(X)

plt.title("Boxplot of Humidity")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ## Simple Linear Regression (without feature scaling)

# %%
les = LinearRegression()
X = X.values.reshape(-1, 1)
les.fit(X,Y)
pred_Y = les.predict(X)

# %%
plt.scatter(X, Y, color="pink", label="Actual Data")
plt.plot(X, pred_Y, color="green", label="Best Fit Line")

plt.xlabel("Independent Variable")
plt.ylabel("Target Variable")
plt.title("Simple Linear Regression")
plt.grid()
plt.legend()

plt.show()

# %%
print("MSE: ", mean_squared_error(Y, pred_Y))
print("RMSE: ", root_mean_squared_error(Y, pred_Y))
print("MAE: ", mean_absolute_error(Y, pred_Y))
print("R2 Score: ", r2_score(Y, pred_Y))
# Out:
# MSE:  54.43749375435016
# RMSE:  7.378176858435298
# MAE:  6.036787588820917
# R2 Score:  0.4042190284669782

# %% [markdown]
# ## Simple Linear Regression with feature scaling and train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
s = StandardScaler()
X_train = s.fit_transform(X_train)
X_test = s.fit_transform(X_test)

# %% [markdown]
# Why we scale after splitting?
#
# If you do: You are letting the model see the information from the test set. This is called data leakage.
#
# Why do we not scale Y:
#
# You only scale: Continuous input features (X)
#
# You don't scale: Target variable

# %%
le2 = LinearRegression()
le2.fit(X_train, Y_train)
pred_Y = le2.predict(X_test)

# %%
plt.scatter(X_train, Y_train, color="red", label="Actual Data")
plt.plot(X_test, pred_Y, color="green", label="Best Fit Line")

plt.xlabel("Independent Variable")
plt.ylabel("Target Variable")
plt.title("Simple Linear Regression")
plt.grid()
plt.legend()

plt.show()

# %%
print("MSE: ", mean_squared_error(Y_test, pred_Y))
print("RMSE: ", root_mean_squared_error(Y_test, pred_Y))
print("MAE: ", mean_absolute_error(Y_test, pred_Y))
print("R2 Score: ", r2_score(Y_test, pred_Y))
# Out:
# MSE:  55.20783509197205
# RMSE:  7.43019751365817
# MAE:  6.064102267513499
# R2 Score:  0.40121487251025834

# %% [markdown]
# ## Multiple Linear Regression (not included for your MidSems)

# %%
X = num_df.drop("Temperature (C)", axis=1)
Y = num_df["Temperature (C)"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
s = StandardScaler()
X_train = s.fit_transform(X_train)
X_test = s.fit_transform(X_test)

# %%
le = LinearRegression()
le.fit(X_train, Y_train)
pred_Y = le.predict(X_test)

# %%
plt.scatter(Y_test, pred_Y)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
print("MSE: ", mean_squared_error(Y_test, pred_Y))
print("RMSE: ", root_mean_squared_error(Y_test, pred_Y))
print("MAE: ", mean_absolute_error(Y_test, pred_Y))
print("R2 Score: ", r2_score(Y_test, pred_Y))
# Out:
# MSE:  50.430776504883426
# RMSE:  7.101462983419926
# MAE:  5.676326776189992
# R2 Score:  0.44692405030109195

# %%
import numpy as np

plt.scatter(Y_test,pred_Y)
plt.plot([min(Y_test), max(Y_test)],
         [min(Y_test), max(Y_test)],
         color="red")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
